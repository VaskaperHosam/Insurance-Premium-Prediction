# %%
import sklearn
sklearn.__version__
# Out:
# '1.4.1.post1'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Imarticus\Cloud\Cloud_Regression\insurance_Premium.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   premium   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region   premium
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# # Missing Value

# %%
df.isna().sum()  # no missing data
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# premium     0
# dtype: int64

# %% [markdown]
# # Outlier

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# # Treatment of Outlier -- Winsorizing Technique

# %%
for i in df:                  # i = column name 
    if df[i].dtypes in ("float64","int64"): # df[i] = every column will select float & int column only
        q1 = df[i].quantile(0.25)  # for 1 column compute q1
        q3 = df[i].quantile(0.75)  # for 1 column compute q3
        iqr = q3-q1  # for 1 column compute IQR
        ul = q3 + 1.5*iqr # for 1 column compute UPPER LIMIT
        ll = q1 - 1.5*iqr # for 1 column compute LOWER LIMIT 
        df[i].clip(lower=ll,upper=ul,inplace=True)

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# #Employee Numeric columns
df_num = df.select_dtypes(include=[np.number])
df_num.head(3)
# Out:
#    age   bmi  children   premium
# 0   19  27.9         0  16884.92
# 1   18  33.8         1   1725.55
# 2   28  33.0         3   4449.46

# %%
df_dummies = df.select_dtypes(include=['object'])
df_dummies.head(3)
# Out:
#       sex smoker     region
# 0  female    yes  southwest
# 1    male     no  southeast
# 2    male     no  southeast

# %%
from sklearn.preprocessing import LabelEncoder

df_dummies = df_dummies.apply(LabelEncoder().fit_transform)
df_dummies.head(3)
# Out:
#    sex  smoker  region
# 0    0       1       3
# 1    1       0       2
# 2    1       0       2

# %%
df = pd.concat([df_num, df_dummies],axis=1)
df.head()
# Out:
#    age   bmi  children   premium  sex  smoker  region
# 0   19  27.9         0  16884.92    0       1       3
# 1   18  33.8         1   1725.55    1       0       2
# 2   28  33.0         3   4449.46    1       0       2
# 3   33  22.7         0  21984.47    1       0       1
# 4   32  28.9         0   3866.86    1       0       1

# %%
df.premium = np.sqrt(df.premium)
df.head()
# Out:
#    age   bmi  children     premium  sex  smoker  region
# 0   19  27.9         0  129.941987    0       1       3
# 1   18  33.8         1   41.539740    1       0       2
# 2   28  33.0         3   66.704273    1       0       2
# 3   33  22.7         0  148.271609    1       0       1
# 4   32  28.9         0   62.184082    1       0       1

# %% [markdown]
# # Data Partition

# %%
X = df.drop('premium', axis= 1)
y = df[['premium']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 ,random_state=134)

# %%
train = pd.concat([y_train, X_train], axis=1)
train.head()
# Out:
#         premium  age   bmi  children  sex  smoker  region
# 234   81.915749   39  24.5         2    1       0       1
# 1016  52.050360   19  24.6         1    0       0       1
# 6     90.777695   46  33.4         1    0       0       2
# 79    81.061828   41  33.0         0    0       0       1
# 309   88.029313   41  33.1         2    0       0       1

# %% [markdown]
# # Model Builiding

# %%
Correlation = train.corr()
Correlation.style.applymap(lambda x: 'background-color : yellow' if x > 0.7 else '')
# Out:
# <style type="text/css">
# #T_84d2f_row0_col0, #T_84d2f_row0_col5, #T_84d2f_row1_col1, #T_84d2f_row2_col2, #T_84d2f_row3_col3, #T_84d2f_row4_col4, #T_84d2f_row5_col0, #T_84d2f_row5_col5, #T_84d2f_row6_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_84d2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84d2f_level0_col0" class="col_heading level0 col0" >premium</th>
#       <th id="T_84d2f_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_84d2f_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_84d2f_level0_col3" class="col_heading level0 col3" >children</th>
#       <th id="T_84d2f_level0_col4" class="col_heading level0 col4" >sex</th>
#       <th id="T_84d2f_level0_col5" class="col_heading level0 col5" >smoker</th>
#       <th id="T_84d2f_level0_col6" class="col_heading level0 col6" >region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84d2f_level0_row0" class="row_heading level0 row0" >premium</th>
#       <td id="T_84d2f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_84d2f_row0_col1" class="data row0 col1" >0.405569</td>
#       <td id="T_84d2f_row0_col2" class="data row0 col2" >0.148619</td>
#       <td id="T_84d2f_row0_col3" class="data row0 col3" >0.089628</td>
#       <td id="T_84d2f_row0_col4" class="data row0 col4" >0.051703</td>
#       <td id="T_84d2f_row0_col5" class="data row0 col5" >0.735183</td>
#       <td id="T_84d2f_row0_col6" class="data row0 col6" >-0.020805</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_84d2f_row1_col0" class="data row1 col0" >0.405569</td>
#       <td id="T_84d2f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_84d2f_row1_col2" class="data row1 col2" >0.124445</td>
#       <td id="T_84d2f_row1_col3" class="data row1 col3" >0.049127</td>
#       <td id="T_84d2f_row1_col4" class="data row1 col4" >0.000447</td>
#       <td id="T_84d2f_row1_col5" class="data row1 col5" >-0.030507</td>
#       <td id="T_84d2f_row1_col6" class="data row1 col6" >0.012153</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row2" class="row_heading level0 row2" >bmi</th>
#       <td id="T_84d2f_row2_col0" class="data row2 col0" >0.148619</td>
#       <td id="T_84d2f_row2_col1" class="data row2 col1" >0.124445</td>
#       <td id="T_84d2f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_84d2f_row2_col3" class="data row2 col3" >0.003821</td>
#       <td id="T_84d2f_row2_col4" class="data row2 col4" >0.050145</td>
#       <td id="T_84d2f_row2_col5" class="data row2 col5" >0.010526</td>
#       <td id="T_84d2f_row2_col6" class="data row2 col6" >0.180525</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row3" class="row_heading level0 row3" >children</th>
#       <td id="T_84d2f_row3_col0" class="data row3 col0" >0.089628</td>
#       <td id="T_84d2f_row3_col1" class="data row3 col1" >0.049127</td>
#       <td id="T_84d2f_row3_col2" class="data row3 col2" >0.003821</td>
#       <td id="T_84d2f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_84d2f_row3_col4" class="data row3 col4" >-0.002856</td>
#       <td id="T_84d2f_row3_col5" class="data row3 col5" >-0.010213</td>
#       <td id="T_84d2f_row3_col6" class="data row3 col6" >0.000438</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row4" class="row_heading level0 row4" >sex</th>
#       <td id="T_84d2f_row4_col0" class="data row4 col0" >0.051703</td>
#       <td id="T_84d2f_row4_col1" class="data row4 col1" >0.000447</td>
#       <td id="T_84d2f_row4_col2" class="data row4 col2" >0.050145</td>
#       <td id="T_84d2f_row4_col3" class="data row4 col3" >-0.002856</td>
#       <td id="T_84d2f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_84d2f_row4_col5" class="data row4 col5" >0.083907</td>
#       <td id="T_84d2f_row4_col6" class="data row4 col6" >-0.024294</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row5" class="row_heading level0 row5" >smoker</th>
#       <td id="T_84d2f_row5_col0" class="data row5 col0" >0.735183</td>
#       <td id="T_84d2f_row5_col1" class="data row5 col1" >-0.030507</td>
#       <td id="T_84d2f_row5_col2" class="data row5 col2" >0.010526</td>
#       <td id="T_84d2f_row5_col3" class="data row5 col3" >-0.010213</td>
#       <td id="T_84d2f_row5_col4" class="data row5 col4" >0.083907</td>
#       <td id="T_84d2f_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_84d2f_row5_col6" class="data row5 col6" >0.004023</td>
#     </tr>
#     <tr>
#       <th id="T_84d2f_level0_row6" class="row_heading level0 row6" >region</th>
#       <td id="T_84d2f_row6_col0" class="data row6 col0" >-0.020805</td>
#       <td id="T_84d2f_row6_col1" class="data row6 col1" >0.012153</td>
#       <td id="T_84d2f_row6_col2" class="data row6 col2" >0.180525</td>
#       <td id="T_84d2f_row6_col3" class="data row6 col3" >0.000438</td>
#       <td id="T_84d2f_row6_col4" class="data row6 col4" >-0.024294</td>
#       <td id="T_84d2f_row6_col5" class="data row6 col5" >0.004023</td>
#       <td id="T_84d2f_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Correlation
# * Resale & Horsepower have high impact on Price of Car

# %%
from sklearn.ensemble import RandomForestRegressor

Model3 = RandomForestRegressor(random_state=20,
                               n_estimators=25, # make 25 tress
                               criterion="squared_error")

Model3.fit(X_train, y_train)
# Out:
# C:\Users\soham\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=25, random_state=20)

# %% [markdown]
# # Prediction on Train

# %%
import numpy as np
train['fitted_value'] = np.round(Model3.predict(X_train),2)
train['Residual'] = np.round(train.premium - train.fitted_value,2)
train
# Out:
#          premium  age   bmi  children  sex  smoker  region  fitted_value  \
# 234    81.915749   39  24.5         2    1       0       1         82.97
# 1016   52.050360   19  24.6         1    0       0       1         52.05
# 6      90.777695   46  33.4         1    0       0       2         91.10
# 79     81.061828   41  33.0         0    0       0       1         80.07
# 309    88.029313   41  33.1         2    0       0       1         87.19
# ...          ...  ...   ...       ...  ...     ...     ...           ...
# 1038   47.443018   22  28.9         0    1       0       0         52.61
# 645   100.703227   48  30.8         3    1       0       0        102.48
# 15     42.863038   19  24.6         1    1       0       3         43.59
# 1202   45.335637   22  32.1         0    1       0       1         44.83
# 114   107.183581   52  32.2         3    1       0       0        113.73
#
#       Residual
# 234      -1.05
# 1016      0.00
# 6        -0.32
# 79        0.99
# 309       0.84
# ...        ...
# 1038     -5.17
# 645      -1.78
# 15       -0.73
# 1202      0.51
# 114      -6.55
#
# [936 rows x 9 columns]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(train.premium,train.fitted_value)
print('R2 score for model Performance on Train : ', np.round(r2,2)*100)
# Out:
# R2 score for model Performance on Train :  96.0

# %% [markdown]
# # Prediction on Test

# %%
test = pd.concat([y_test, X_test], axis=1)
test.head()
# Out:
#          premium  age   bmi  children  sex  smoker  region
# 894   116.425942   62  32.1         0    1       0       0
# 1041   41.288013   18  23.1         0    1       0       0
# 957   112.293767   24  26.8         1    1       0       1
# 45    143.632448   55  37.3         0    1       0       3
# 483    99.398541   51  39.5         1    0       0       3

# %%
import numpy as np
test['Prediction'] = np.round(Model3.predict(X_test),2)
test['Residual'] = np.round(test.premium - test.Prediction,2)
test.head()
# Out:
#          premium  age   bmi  children  sex  smoker  region  Prediction  \
# 894   116.425942   62  32.1         0    1       0       0      117.00
# 1041   41.288013   18  23.1         0    1       0       0       44.11
# 957   112.293767   24  26.8         1    1       0       1       55.91
# 45    143.632448   55  37.3         0    1       0       3      107.07
# 483    99.398541   51  39.5         1    0       0       3       99.25
#
#       Residual
# 894      -0.57
# 1041     -2.82
# 957      56.38
# 45       36.56
# 483       0.15

# %% [markdown]
# # Comparision

# %%
from sklearn.metrics import r2_score
r2 = r2_score(train.premium,train.fitted_value)
print('R2 score for model Performance on Train : ', np.round(r2,2)*100)
# Out:
# R2 score for model Performance on Train :  96.0

# %%
r2 = r2_score(test.premium,test.Prediction)
print('R2 score for model Performance on Test : ', np.round(r2,2)*100)
# Out:
# R2 score for model Performance on Test :  85.0

# %% [markdown]
# # Finished

# %% [markdown]
# # Model Export

# %%
import sklearn
sklearn.__version__
# Out:
# '1.4.1.post1'

# %%
import pickle

pickle.dump(Model3, open(r"D:\Imarticus\Cloud\Cloud_Regression/build.pkl",'wb'))  #model = dt # Exporting model from python to laptop

# %%
X_train.head()
# Out:
#       age   bmi  children  sex  smoker  region
# 234    39  24.5         2    1       0       1
# 1016   19  24.6         1    0       0       1
# 6      46  33.4         1    0       0       2
# 79     41  33.0         0    0       0       1
# 309    41  33.1         2    0       0       1
